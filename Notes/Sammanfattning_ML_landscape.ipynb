# %% [markdown]
# ## Machine learning landscape

# %% [markdown]
# ***Learning paradigms***
#
#     Supervised learning (övervakad inlärning)
# Modellen tränas på data där både input och korrekt output finns.
# - Self‑supervised learning — modellen skapar egna labels genom att dölja delar av input och försöka förutsäga dem (t.ex. maskera en del av en bild och låta modellen gissa vad som saknas).
# - Semi‑supervised learning — kombinerar en liten mängd märkt data med en stor mängd omärkt data.
#
# Unsupervised learning (oövervakad inlärning)
#
# Modellen får endast input och försöker hitta mönster, strukturer eller grupperingar.
#
# Reinforcement learning (förstärkningsinlärning)
#
# En agent lär sig genom att interagera med en miljö och få belöningar eller straff, med målet att maximera långsiktig reward.
#
# ***Task‑typer***
#
# - **Regression** — förutsäga kontinuerliga värden.
# - **Classification** — förutsäga kategorier.
# - **Clustering** — gruppera data utan labels.
# - **Dimensionality reduction (komprimering)** — minska antalet features men behåll viktig information.
# - **Anomaly detection** — upptäcka avvikande beteenden som inte borde hända.
# - **Novelty detection** — upptäcka nya mönster som vi vill hitta.
#
# ***Training‑strategier***
#
# Både batch och online learning sker i praktiken offline — skillnaden ligger i hur modellen uppdateras.
#
# - **Batch learning** — modellen tränas på hela datasetet eller stora batchar åt gången; kräver retraining vid ny data.
# - **Online learning** — modellen uppdateras kontinuerligt när ny data kommer in.
#
# *** Model types***
# - **Instance‑based (non‑generalizing)** — modellen lagrar instanser och jämför ny data direkt mot tidigare exempel.
#
# Exempel: k‑Nearest Neighbors (kNN).
# - **Model‑based** — modellen lär en generell funktion f(x) som kan generalisera till ny data.
#
# Exempel: linjär regression, neurala nätverk, decision trees.
#
# <img src="Data/bild_1.png" width="700">

# %% [markdown]
# Vi har inte inferenser, så i ML måste vi testa.
#
# Detta leder till många förvirringar mellan ML och statistik.
#
# Tolkning av konfidensintervall (se L1.Monte_Carlo.ipynb)

# %% [markdown]
# **Allmän linjär regression (General Linear Models, GLM)**
# ### DETTA ÄR STATISTIK
#
# F-test      (ANOVA, ANCOVA) analyse of variance, Analyse of covariance,
#
# t-test
#
# I statistiken förenklade vi till en responsvariabel Y, men om vi har kategoriska kolumner kan vi se Y som flera Y1, Y2... osv.
#
# Linjär, multipel, polynomiell, poisson, logistisk ([0, 1]) regression
#
# Normalantagande "överallt".
#
# $[
# Y = X\boldsymbol{\beta} + \varepsilon
# ]$
#
# **När vi går över till ML överger vi vårt normalantagande. Statistik som ovan gäller inte längre.**
#
# ## Generalized Linear Models
#
# Vi överger nu alltså normalantagandet, att vår prediktor är normalfördelad. Nu kan vi förutsäga utifrån en binomiell eller geometrisk eller dylikt.
#
# <img src="Data/gen_lin_models.png" width="400">

# %% [markdown]
# ## Sammanfattning av GLM‑intuitionen
#
# En GLM kräver tre komponenter:
#
# - **En fördelning för \(Y\)** (normal, gamma, Bernoulli, Poisson, binomial).
# - **En linjär prediktor** $\eta = X\beta$.
# - **En länkfunktion** \(g\) som omvandlar $\mu = E(Y)$ till något som kan modelleras linjärt.
#
# Grundidén är att välja en transformation av data så att den linjära modellen fungerar.
#
# ---
#
# ### Kontinuerliga värden över hela reala linjen
# - Dataområde: \((-$\infty, +\infty$)\).
# - Fördelning: normal.
# - Länk: identitet.
# - Detta är vanlig linjär regression.
#
# ---
#
# ### Positiva kontinuerliga värden
# - Dataområde: \((0, +$\infty$)\).
# - Fördelning: gamma eller exponentiell.
# - Länk: inverse eller log.
# - Användning: när variansen ökar med medelvärdet, t.ex. väntetider.
# - Kan vara användbart i anomaly detection när små förändringar ger stora relativa effekter.
#
# ---
#
# ### Binära utfall (0/1)
# - Fördelning: Bernoulli.
# - Länk: logit.
# - Användning: klassificering och sannolikhetsmodellering.
#
# ---
#
# ### Antal träffar av \(n\) försök
# - Fördelning: binomial.
# - Länk: logit.
# - Användning: räkna förekomster inom ett fast antal försök.
#
# ---
#
# ### Antal händelser (0, 1, 2, …)
# - Fördelning: Poisson.
# - Länk: log.
# - Användning: händelser per tidsenhet, fel, kundflöden, anomaly detection.
#
# ---
#
# ## Estimering i GLM
# När vi lämnar linjär regression fungerar inte minsta kvadrat längre.
# I stället används:
#
# - **Maximum Likelihood Estimation (MLE)** som standard.
# - **Bayesianska metoder** (t.ex. Gibbs sampling, Monte Carlo) vid mer komplexa modeller eller när man vill ha posteriorfördelningar.

# %% [markdown]
# | Modell               | Fördelning | Dataområde            | Länkfunktion |
# | -------------------- | ---------- | --------------------- | ------------ |
# | Linjär regression    | Normal     | ( (-$\infty$, $\infty$) ) | Identitet    |
# | Logistisk regression | Bernoulli  | {0,1}                 | Logit        |
# | Binomial regression  | Binomial   | 0…n                   | Logit        |
# | Poisson regression   | Poisson    | 0,1,2…                | Log          |
# | Gamma regression     | Gamma      | ( (0,$\infty$) )        | Invers / Log |
#
# <img src="Data/slide_3.png" width="600">

# %% [markdown]
# ### Gradient descent (Gås igenom i L2.Gradient_descent.ipynb)
#
# Normalt sett: hitta derivata, sätt till 0, analysera inflection point
#
# GD: Iteratively **descend** in the direction where change is greatest. Naturligt sätt att hitta inflection point med hjälp av flera steg av GD.
# Finns inget stoppvillkor. Måste säga "Sluta" till programmet tillslut, den kommer annars hoppa i all evighet runt omkring punkten.
# Man kan sätta steglängden själv.
#
# "G D doesn't terminate! We need a stop condition"
#
# **Step length** is called **"learning rate"** .
#
# Har vi en väldigt liten learning rate så tar den väldigt små steg, och ställer vi då ett stop på 10 steg kommer den inte hinna klart. Vi kan sätta ett stoppvillkor att om den inte förändras över en viss längd i ex 10 steg, så stoppas programmet.
#
# Ett för litet steg kommer missa, en för stor learning rate kommer göra att den hoppar över optimumet.
#
# Adaptive learning rate - sätter en exponentiell learning rate.
#
# <img src="Data/learningrate1.png" width="600">

# %% [markdown]
# Kan ofta finnas flera optimum, hur blir det då?
# **Lokala** och **globala** optimum.
#
# ### **ADAM** - Adaptive Descent with Momentum
# decreases with epoch. (kolla upp)
#
# Momentum: We add a physics-like condition to the cost function, that really acts like momentum (**tröghet**).
#
# <img src="Data/ADAM.png" width="500">

# %% [markdown]
# Hur fungerar detta i 3D? Istället för att kolla lutningen av linjer så kollar vi istället på lutningen av plan.
# Istället för att använda derivatan använder vi gradienten.
#
# *"Gradient always points in direction of largest change."*
#
# <img src="Data/3D.png" width="200">

# %% [markdown]
# If we evaluate all points in the data:
#
# **Batch gradient descent**
# - expensive
# - good results
#
# one step:
#
# $\theta_{n+1} = \theta_n - \eta \nabla_{\theta}  \mathrm{MSE}(\theta)$
#
# Evaluated at each point for each parameter, Too expensive!!
#
# **Stochastic Gradient Descent**
#
# <img src="Data/StochasticGD.png" width="200">

# %% [markdown]
# *May or may not work... it's random!*
#
# Choose a random point, derive at that point, take a small step.

# %% [markdown]
# **Mini-batch Gradient Descent**
# Choose a random sample of points (stickprov av viss storlek).
# - Evaluate, descend (take a step)
#
# ***By far the most common!***

# %% [markdown]
# ![Stochastic Gradient Descent](Data/StochasticGD.png)

# %% [markdown]
# För att titta på hur bra en regression går kollar vi i ML: **MAE**, **MSE** och **RMSE**

# %% [markdown]
# Räta ut skillnad mellan cost function och loss function
#
# $\hat{y} = wx$
#
# fel = $(\hat{y} - y)^2$
#
# $\ell_i(w) = (w x_i - y_i)^2$ $\eta$

# %% [markdown]
# Recall: TP/TP+FN "Av alla riktiga bränder, hur många upptäckte vi?"
# Precision: TP/TP+FP "Hur ofta faktiskt brand vid larm"
# Accuracy: TP + FP/TOTAL "Hur ofta rätt"
#
# F1: 2 * (Precision*Recall) / (Precision + Recall)
#
# Kolla F1, F2, vad är det

# %% [markdown]
# För labb:
